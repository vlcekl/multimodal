# %% [markdown]
# # Dimensionality reduction of citeseq data

# %%
import sys, os, gc
import numpy as np
import scipy.sparse
import pandas as pd
import tables

import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import GroupKFold, train_test_split
from sklearn.multioutput import MultiOutputClassifier, ClassifierChain
from sklearn.metrics import accuracy_score, mean_squared_error, log_loss, confusion_matrix
from lightgbm import LGBMClassifier
from tune_sklearn import TuneSearchCV

import tensorflow as tf

# %%
#!pip install --quiet tables

# %%
sys.path.append('../src/')
from utils import make_cite_train, make_cite_test

# %%
# Objective function
def correlation_score(y_true, y_pred):
    """Scores the predictions according to the competition rules. 
    
    It is assumed that the predictions are not constant.
    
    Returns the average of each sample's Pearson correlation coefficient"""
    if type(y_true) == pd.DataFrame: y_true = y_true.values
    if type(y_pred) == pd.DataFrame: y_pred = y_pred.values
    corrsum = 0
    for i in range(len(y_true)):
        corrsum += np.corrcoef(y_true[i], y_pred[i])[1, 0]
    return corrsum / len(y_true)

# %%
#DATA_DIR = os.path.join('kaggle/input', os.listdir(kgl_input)[0])
DATA_DIR = '../data'
#os.listdir(DATA_DIR)

# %%
PATH_METADATA = os.path.join(DATA_DIR, 'metadata.csv')
PATH_TRAIN_CITE_INPUTS = os.path.join(DATA_DIR, 'train_cite_inputs.h5')
PATH_TRAIN_CITE_TARGETS = os.path.join(DATA_DIR, 'train_cite_targets.h5')

PATH_METADATA2 = os.path.join(DATA_DIR, 'metadata_cite_day_2_donor_27678.csv')
PATH_TEST_CITE_INPUTS = os.path.join(DATA_DIR, 'test_cite_inputs.h5')
PATH_TEST_CITE_INPUTS2 = os.path.join(DATA_DIR, 'test_cite_inputs_day_2_donor_27678.h5')

# %%
x_train, y_train, meta_train = make_cite_train(PATH_TRAIN_CITE_INPUTS, PATH_TRAIN_CITE_TARGETS, PATH_METADATA)
gc.collect()

x_test, meta_test = make_cite_test(PATH_TEST_CITE_INPUTS, PATH_TEST_CITE_INPUTS2, PATH_METADATA, PATH_METADATA2)
gc.collect()
# Out:
# 0

# %%
meta_df = pd.read_csv(PATH_METADATA)

# %%
meta_test[meta_test.day == 7]
# Out:
#               day  donor cell_type
# c0389aaf4d91    7  27678      MasP
# a08143be038f    7  27678       HSC
# 84759d69ca13    7  27678      MasP
# a3e96e3bd293    7  27678      MasP
# 70d4c868ba25    7  27678       HSC
# ...           ...    ...       ...
# a9b4d99f1f50    7  31800       HSC
# 0e2c1d0782af    7  31800       HSC
# a3cbc5aa0ec3    7  31800       MkP
# 75b350243add    7  31800      EryP
# ad5a949989b2    7  31800      EryP
#
# [26867 rows x 3 columns]

# %%
# Add day into feature set
y_train = pd.concat([y_train, meta_train[['day']]], axis=1)

# %%
#y_train.drop(columns=['day'], inplace=True)

# %%
# Proteins in the training targets (use them now to develop a cell type classification model)
X = scipy.sparse.csr_matrix(y_train)
# Classify cell types based on proteins
Y = meta_train[['cell_type']].astype('category').values

# %%
X.shape, Y.shape
# Out:
# ((70988, 141), (70988, 1))

# %%
lightgbm_params = {
     'boosting_type': 'goss',
     'learning_rate': 0.1, 
     'max_depth': 10, 
     'num_leaves': 200,
     'min_child_samples': 250,
     'colsample_bytree': 0.8, 
     'subsample': 0.6, 
     "seed": 1
    }

# %%
# %%time

CROSS_VALIDATE = True
if CROSS_VALIDATE:
    y_cols = Y.shape[1] # set this to a small number for a quick test
    n_estimators = 300

    kf = GroupKFold(n_splits=3)
    
    score_list = []
    for fold, (idx_tr, idx_va) in enumerate(kf.split(X, groups=meta_train.donor)):
        print('i:', fold, 't:', idx_tr, 'v:', idx_va)

        model = None
        gc.collect()

        X_tr = X[idx_tr]
        y_tr = Y[:,:y_cols][idx_tr]
        X_va = X[idx_va]
        y_va = Y[:,:y_cols][idx_va]

        models, va_preds, va_preds_proba = [], [], []
        for i in range(y_cols):
            print(f"Training column {i:3} for validation")
            model = LGBMClassifier(n_estimators=n_estimators, **lightgbm_params, n_jobs=6)
            # models.append(model) # not needed
            print('fitting')
            model.fit(X_tr, y_tr[:,i].copy())
            print('predicting')
            va_preds.append(model.predict(X_va))
            print('predicting proba')
            va_preds_proba.append(model.predict_proba(X_va))

        y_va_pred = np.column_stack(va_preds) # concatenate the 140 predictions
        y_va_pred_proba = np.column_stack(va_preds_proba) # concatenate the 140 predictions

        del va_preds
        del va_preds_proba
        del X_tr, y_tr, X_va
        gc.collect()
        print('scoring')
        # We validate the model (mse and correlation over all 140 columns)
        #mse = mean_squared_error(y_va, y_va_pred)
        #corrscore = correlation_score(y_va, y_va_pred)
        mse = accuracy_score(y_va, y_va_pred)
        corrscore = accuracy_score(y_va, y_va_pred)
        acc_score = accuracy_score(y_va, y_va_pred)
        #log_score = accuracy_score(y_va, y_va_pred)
        log_score = log_loss(y_va, y_va_pred_proba)
        
        print('Confusion Matrix')
        print(confusion_matrix(y_va, y_va_pred))

        del y_va

        print(f"Fold {fold} {X.shape[1]:4}: mse = {mse:.5f}, acc =  {acc_score:.5f}, log = {log_score: 5f}")
        score_list.append((mse, corrscore, acc_score, log_score))
        #break # We only need the first fold

    if len(score_list) > 1:
        # Show overall score
        result_df = pd.DataFrame(score_list, columns=['mse', 'corrscore', 'acc_score', 'log_score'])
        print(f"Average LGBM mse = {result_df.mse.mean():.5f}; corr = {result_df.corrscore.mean():.5f}; acc = {result_df.acc_score.mean():0.5f}; log = {result_df.log_score.mean():0.5f}")
# Out:
# i: 0 t: [    0     1     2 ... 46182 46183 46184] v: [46185 46186 46187 ... 70985 70986 70987]
# Training column   0 for validation
# fitting
# predicting
# predicting proba
# scoring
# Confusion Matrix
# [[   0    1   44    1    4    0    7]
#  [   0 4604   27   73  319    0   10]
#  [   0    6 9678   34  159    3  378]
#  [   0  276  115 1960  225    1  219]
#  [   0  364  497  109 1023    0   96]
#  [   0   36   25    0   65  134   63]
#  [   0    4  549   82   16    4 3592]]
# Fold 0  141: mse = 0.84631, acc =  0.84631, log =  0.513242
# i: 1 t: [23986 23987 23988 ... 70985 70986 70987] v: [    0     1     2 ... 23983 23984 23985]
# Training column   0 for validation
# fitting
# predicting
# predicting proba
# scoring
# Confusion Matrix
# [[   0    6   30    8    6    0    0]
#  [   0 4478   21  307  127    1   12]
#  [   0   17 9131   28  189    3  384]
#  [   0  128   81 2608  174    1  205]
#  [   0  239  316  225  608    0   73]
#  [   0    4   24    3    4   76   20]
#  [   0    6  683  113   27    5 3615]]
# Fold 1  141: mse = 0.85533, acc =  0.85533, log =  0.445323
# i: 2 t: [    0     1     2 ... 70985 70986 70987] v: [23986 23987 23988 ... 46182 46183 46184]
# Training column   0 for validation
# fitting
# predicting
# predicting proba
# scoring
# Confusion Matrix
# [[   0    2   32    5    9    5    0]
#  [   0 3634   37  196  389    0    6]
#  [   0   26 9143   63  352    0  285]
#  [   0  129   49 1776  184    0  111]
#  [   0  296  356  139 1003    0   38]
#  [   0    2   14    2   11   95   13]
#  [   0   20  712  186   44    9 2826]]
# Fold 2  141: mse = 0.83233, acc =  0.83233, log =  0.488114
# Average LGBM mse = 0.84466; corr = 0.84466; acc = 0.84466; log = 0.48223
# CPU times: user 3min 31s, sys: 567 ms, total: 3min 31s
# Wall time: 35.9 s

# %% [markdown]
# ## Optimize hyperparamters

# %%
param_dists = {
     'learning_rate': [0.05, 0.2], 
     'max_depth': [5, 20], 
     'num_leaves': [100, 300],
     'min_child_samples': [150, 350],
     'colsample_bytree': [0.6, 0.9], 
     'subsample': [0.5, 0.7]
    }

# %%
y = Y[:,0]

# %%
lgbm = LGBMClassifier(
    boosting_type='goss',
    n_jobs = 6,
    seed=1
)

lgbm_cv = TuneSearchCV(
    estimator=lgbm,
    param_distributions=param_dists,
    search_optimization="bayesian",
    cv=GroupKFold(n_splits=3),
    scoring = 'accuracy',
    n_trials=10,
    early_stopping=True,
    max_iters=20,
    n_jobs=1,
    verbose=2
)

# %%
# %%time

lgbm_cv.fit(X, y, groups=meta_train.donor)
# Out:
# (pid=15008) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest` has been moved to `ray.tune.search` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest` with `ray.tune.search`.
# (pid=15008)   from ray.tune.suggest.suggestion import Searcher
# (pid=15008) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest.suggestion` has been moved to `ray.tune.search.searcher` and the old location will be deprecated soon. Please adjust your imports to point to the new location.
# (pid=15008) ATTENTION: This module may have been split or refactored. Please check the contents of `ray.tune.search.searcher` before making changes.
# (pid=15008)   from ray.tune.suggest.suggestion import Searcher
# (pid=15008) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_basesearch.py:33: DeprecationWarning: The module `ray.tune.trial` has been moved to `ray.tune.experiment.trial` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.trial` with `ray.tune.experiment.trial`.
# (pid=15008)   from ray.tune.trial import Trial
# (pid=15008) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:12: DeprecationWarning: The module `ray.tune.sample` has been moved to `ray.tune.search.sample` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.sample` with `ray.tune.search.sample`.
# (pid=15008)   from ray.tune.sample import Domain
# (pid=15008) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:15: DeprecationWarning: The module `ray.tune.suggest.bohb` has been moved to `ray.tune.search.bohb` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.bohb` with `ray.tune.search.bohb`.
# (pid=15008)   from ray.tune.suggest.bohb import TuneBOHB
# (pid=15008) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:18: DeprecationWarning: The module `ray.tune.suggest.skopt` has been moved to `ray.tune.search.skopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.skopt` with `ray.tune.search.skopt`.
# (pid=15008)   from ray.tune.suggest.skopt import SkOptSearch
# (pid=15008) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:19: DeprecationWarning: The module `ray.tune.suggest.hyperopt` has been moved to `ray.tune.search.hyperopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.hyperopt` with `ray.tune.search.hyperopt`.
# (pid=15008)   from ray.tune.suggest.hyperopt import HyperOptSearch
# (pid=15008) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:20: DeprecationWarning: The module `ray.tune.suggest.optuna` has been moved to `ray.tune.search.optuna` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.optuna` with `ray.tune.search.optuna`.
# (pid=15008)   from ray.tune.suggest.optuna import OptunaSearch
# (pid=22659) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest` has been moved to `ray.tune.search` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest` with `ray.tune.search`.
# (pid=22659)   from ray.tune.suggest.suggestion import Searcher
# (pid=22659) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest.suggestion` has been moved to `ray.tune.search.searcher` and the old location will be deprecated soon. Please adjust your imports to point to the new location.
# (pid=22659) ATTENTION: This module may have been split or refactored. Please check the contents of `ray.tune.search.searcher` before making changes.
# (pid=22659)   from ray.tune.suggest.suggestion import Searcher
# (pid=22659) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_basesearch.py:33: DeprecationWarning: The module `ray.tune.trial` has been moved to `ray.tune.experiment.trial` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.trial` with `ray.tune.experiment.trial`.
# (pid=22659)   from ray.tune.trial import Trial
# (pid=22659) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:12: DeprecationWarning: The module `ray.tune.sample` has been moved to `ray.tune.search.sample` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.sample` with `ray.tune.search.sample`.
# (pid=22659)   from ray.tune.sample import Domain
# (pid=22659) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:15: DeprecationWarning: The module `ray.tune.suggest.bohb` has been moved to `ray.tune.search.bohb` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.bohb` with `ray.tune.search.bohb`.
# (pid=22659)   from ray.tune.suggest.bohb import TuneBOHB
# (pid=22659) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:18: DeprecationWarning: The module `ray.tune.suggest.skopt` has been moved to `ray.tune.search.skopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.skopt` with `ray.tune.search.skopt`.
# (pid=22659)   from ray.tune.suggest.skopt import SkOptSearch
# (pid=22659) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:19: DeprecationWarning: The module `ray.tune.suggest.hyperopt` has been moved to `ray.tune.search.hyperopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.hyperopt` with `ray.tune.search.hyperopt`.
# (pid=22659)   from ray.tune.suggest.hyperopt import HyperOptSearch
# (pid=22659) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:20: DeprecationWarning: The module `ray.tune.suggest.optuna` has been moved to `ray.tune.search.optuna` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.optuna` with `ray.tune.search.optuna`.
# (pid=22659)   from ray.tune.suggest.optuna import OptunaSearch
# (pid=22752) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest` has been moved to `ray.tune.search` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest` with `ray.tune.search`.
# (pid=22752)   from ray.tune.suggest.suggestion import Searcher
# (pid=22752) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest.suggestion` has been moved to `ray.tune.search.searcher` and the old location will be deprecated soon. Please adjust your imports to point to the new location.
# (pid=22752) ATTENTION: This module may have been split or refactored. Please check the contents of `ray.tune.search.searcher` before making changes.
# (pid=22752)   from ray.tune.suggest.suggestion import Searcher
# (pid=22752) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_basesearch.py:33: DeprecationWarning: The module `ray.tune.trial` has been moved to `ray.tune.experiment.trial` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.trial` with `ray.tune.experiment.trial`.
# (pid=22752)   from ray.tune.trial import Trial
# (pid=22752) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:12: DeprecationWarning: The module `ray.tune.sample` has been moved to `ray.tune.search.sample` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.sample` with `ray.tune.search.sample`.
# (pid=22752)   from ray.tune.sample import Domain
# (pid=22752) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:15: DeprecationWarning: The module `ray.tune.suggest.bohb` has been moved to `ray.tune.search.bohb` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.bohb` with `ray.tune.search.bohb`.
# (pid=22752)   from ray.tune.suggest.bohb import TuneBOHB
# (pid=22752) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:18: DeprecationWarning: The module `ray.tune.suggest.skopt` has been moved to `ray.tune.search.skopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.skopt` with `ray.tune.search.skopt`.
# (pid=22752)   from ray.tune.suggest.skopt import SkOptSearch
# (pid=22752) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:19: DeprecationWarning: The module `ray.tune.suggest.hyperopt` has been moved to `ray.tune.search.hyperopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.hyperopt` with `ray.tune.search.hyperopt`.
# (pid=22752)   from ray.tune.suggest.hyperopt import HyperOptSearch
# (pid=22752) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:20: DeprecationWarning: The module `ray.tune.suggest.optuna` has been moved to `ray.tune.search.optuna` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.optuna` with `ray.tune.search.optuna`.
# (pid=22752)   from ray.tune.suggest.optuna import OptunaSearch
# (pid=26272) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest` has been moved to `ray.tune.search` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest` with `ray.tune.search`.
# (pid=26272)   from ray.tune.suggest.suggestion import Searcher
# (pid=26272) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest.suggestion` has been moved to `ray.tune.search.searcher` and the old location will be deprecated soon. Please adjust your imports to point to the new location.
# (pid=26272) ATTENTION: This module may have been split or refactored. Please check the contents of `ray.tune.search.searcher` before making changes.
# (pid=26272)   from ray.tune.suggest.suggestion import Searcher
# (pid=26272) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_basesearch.py:33: DeprecationWarning: The module `ray.tune.trial` has been moved to `ray.tune.experiment.trial` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.trial` with `ray.tune.experiment.trial`.
# (pid=26272)   from ray.tune.trial import Trial
# (pid=26272) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:12: DeprecationWarning: The module `ray.tune.sample` has been moved to `ray.tune.search.sample` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.sample` with `ray.tune.search.sample`.
# (pid=26272)   from ray.tune.sample import Domain
# (pid=26272) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:15: DeprecationWarning: The module `ray.tune.suggest.bohb` has been moved to `ray.tune.search.bohb` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.bohb` with `ray.tune.search.bohb`.
# (pid=26272)   from ray.tune.suggest.bohb import TuneBOHB
# (pid=26272) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:18: DeprecationWarning: The module `ray.tune.suggest.skopt` has been moved to `ray.tune.search.skopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.skopt` with `ray.tune.search.skopt`.
# (pid=26272)   from ray.tune.suggest.skopt import SkOptSearch
# (pid=26272) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:19: DeprecationWarning: The module `ray.tune.suggest.hyperopt` has been moved to `ray.tune.search.hyperopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.hyperopt` with `ray.tune.search.hyperopt`.
# (pid=26272)   from ray.tune.suggest.hyperopt import HyperOptSearch
# (pid=26272) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:20: DeprecationWarning: The module `ray.tune.suggest.optuna` has been moved to `ray.tune.search.optuna` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.optuna` with `ray.tune.search.optuna`.
# (pid=26272)   from ray.tune.suggest.optuna import OptunaSearch
# (pid=26402) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest` has been moved to `ray.tune.search` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest` with `ray.tune.search`.
# (pid=26402)   from ray.tune.suggest.suggestion import Searcher
# (pid=26402) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest.suggestion` has been moved to `ray.tune.search.searcher` and the old location will be deprecated soon. Please adjust your imports to point to the new location.
# (pid=26402) ATTENTION: This module may have been split or refactored. Please check the contents of `ray.tune.search.searcher` before making changes.
# (pid=26402)   from ray.tune.suggest.suggestion import Searcher
# (pid=26402) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_basesearch.py:33: DeprecationWarning: The module `ray.tune.trial` has been moved to `ray.tune.experiment.trial` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.trial` with `ray.tune.experiment.trial`.
# (pid=26402)   from ray.tune.trial import Trial
# (pid=26402) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:12: DeprecationWarning: The module `ray.tune.sample` has been moved to `ray.tune.search.sample` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.sample` with `ray.tune.search.sample`.
# (pid=26402)   from ray.tune.sample import Domain
# (pid=26402) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:15: DeprecationWarning: The module `ray.tune.suggest.bohb` has been moved to `ray.tune.search.bohb` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.bohb` with `ray.tune.search.bohb`.
# (pid=26402)   from ray.tune.suggest.bohb import TuneBOHB
# (pid=26402) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:18: DeprecationWarning: The module `ray.tune.suggest.skopt` has been moved to `ray.tune.search.skopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.skopt` with `ray.tune.search.skopt`.
# (pid=26402)   from ray.tune.suggest.skopt import SkOptSearch
# (pid=26402) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:19: DeprecationWarning: The module `ray.tune.suggest.hyperopt` has been moved to `ray.tune.search.hyperopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.hyperopt` with `ray.tune.search.hyperopt`.
# (pid=26402)   from ray.tune.suggest.hyperopt import HyperOptSearch
# (pid=26402) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:20: DeprecationWarning: The module `ray.tune.suggest.optuna` has been moved to `ray.tune.search.optuna` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.optuna` with `ray.tune.search.optuna`.
# (pid=26402)   from ray.tune.suggest.optuna import OptunaSearch
# (pid=26528) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest` has been moved to `ray.tune.search` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest` with `ray.tune.search`.
# (pid=26528)   from ray.tune.suggest.suggestion import Searcher
# (pid=26528) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest.suggestion` has been moved to `ray.tune.search.searcher` and the old location will be deprecated soon. Please adjust your imports to point to the new location.
# (pid=26528) ATTENTION: This module may have been split or refactored. Please check the contents of `ray.tune.search.searcher` before making changes.
# (pid=26528)   from ray.tune.suggest.suggestion import Searcher
# (pid=26528) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_basesearch.py:33: DeprecationWarning: The module `ray.tune.trial` has been moved to `ray.tune.experiment.trial` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.trial` with `ray.tune.experiment.trial`.
# (pid=26528)   from ray.tune.trial import Trial
# (pid=26528) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:12: DeprecationWarning: The module `ray.tune.sample` has been moved to `ray.tune.search.sample` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.sample` with `ray.tune.search.sample`.
# (pid=26528)   from ray.tune.sample import Domain
# (pid=26528) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:15: DeprecationWarning: The module `ray.tune.suggest.bohb` has been moved to `ray.tune.search.bohb` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.bohb` with `ray.tune.search.bohb`.
# (pid=26528)   from ray.tune.suggest.bohb import TuneBOHB
# (pid=26528) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:18: DeprecationWarning: The module `ray.tune.suggest.skopt` has been moved to `ray.tune.search.skopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.skopt` with `ray.tune.search.skopt`.
# (pid=26528)   from ray.tune.suggest.skopt import SkOptSearch
# (pid=26528) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:19: DeprecationWarning: The module `ray.tune.suggest.hyperopt` has been moved to `ray.tune.search.hyperopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.hyperopt` with `ray.tune.search.hyperopt`.
# (pid=26528)   from ray.tune.suggest.hyperopt import HyperOptSearch
# (pid=26528) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:20: DeprecationWarning: The module `ray.tune.suggest.optuna` has been moved to `ray.tune.search.optuna` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.optuna` with `ray.tune.search.optuna`.
# (pid=26528)   from ray.tune.suggest.optuna import OptunaSearch
# (pid=26621) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest` has been moved to `ray.tune.search` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest` with `ray.tune.search`.
# (pid=26621)   from ray.tune.suggest.suggestion import Searcher
# (pid=26621) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest.suggestion` has been moved to `ray.tune.search.searcher` and the old location will be deprecated soon. Please adjust your imports to point to the new location.
# (pid=26621) ATTENTION: This module may have been split or refactored. Please check the contents of `ray.tune.search.searcher` before making changes.
# (pid=26621)   from ray.tune.suggest.suggestion import Searcher
# (pid=26621) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_basesearch.py:33: DeprecationWarning: The module `ray.tune.trial` has been moved to `ray.tune.experiment.trial` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.trial` with `ray.tune.experiment.trial`.
# (pid=26621)   from ray.tune.trial import Trial
# (pid=26621) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:12: DeprecationWarning: The module `ray.tune.sample` has been moved to `ray.tune.search.sample` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.sample` with `ray.tune.search.sample`.
# (pid=26621)   from ray.tune.sample import Domain
# (pid=26621) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:15: DeprecationWarning: The module `ray.tune.suggest.bohb` has been moved to `ray.tune.search.bohb` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.bohb` with `ray.tune.search.bohb`.
# (pid=26621)   from ray.tune.suggest.bohb import TuneBOHB
# (pid=26621) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:18: DeprecationWarning: The module `ray.tune.suggest.skopt` has been moved to `ray.tune.search.skopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.skopt` with `ray.tune.search.skopt`.
# (pid=26621)   from ray.tune.suggest.skopt import SkOptSearch
# (pid=26621) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:19: DeprecationWarning: The module `ray.tune.suggest.hyperopt` has been moved to `ray.tune.search.hyperopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.hyperopt` with `ray.tune.search.hyperopt`.
# (pid=26621)   from ray.tune.suggest.hyperopt import HyperOptSearch
# (pid=26621) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:20: DeprecationWarning: The module `ray.tune.suggest.optuna` has been moved to `ray.tune.search.optuna` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.optuna` with `ray.tune.search.optuna`.
# (pid=26621)   from ray.tune.suggest.optuna import OptunaSearch
# (pid=26716) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest` has been moved to `ray.tune.search` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest` with `ray.tune.search`.
# (pid=26716)   from ray.tune.suggest.suggestion import Searcher
# (pid=26716) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest.suggestion` has been moved to `ray.tune.search.searcher` and the old location will be deprecated soon. Please adjust your imports to point to the new location.
# (pid=26716) ATTENTION: This module may have been split or refactored. Please check the contents of `ray.tune.search.searcher` before making changes.
# (pid=26716)   from ray.tune.suggest.suggestion import Searcher
# (pid=26716) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_basesearch.py:33: DeprecationWarning: The module `ray.tune.trial` has been moved to `ray.tune.experiment.trial` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.trial` with `ray.tune.experiment.trial`.
# (pid=26716)   from ray.tune.trial import Trial
# (pid=26716) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:12: DeprecationWarning: The module `ray.tune.sample` has been moved to `ray.tune.search.sample` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.sample` with `ray.tune.search.sample`.
# (pid=26716)   from ray.tune.sample import Domain
# (pid=26716) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:15: DeprecationWarning: The module `ray.tune.suggest.bohb` has been moved to `ray.tune.search.bohb` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.bohb` with `ray.tune.search.bohb`.
# (pid=26716)   from ray.tune.suggest.bohb import TuneBOHB
# (pid=26716) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:18: DeprecationWarning: The module `ray.tune.suggest.skopt` has been moved to `ray.tune.search.skopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.skopt` with `ray.tune.search.skopt`.
# (pid=26716)   from ray.tune.suggest.skopt import SkOptSearch
# (pid=26716) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:19: DeprecationWarning: The module `ray.tune.suggest.hyperopt` has been moved to `ray.tune.search.hyperopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.hyperopt` with `ray.tune.search.hyperopt`.
# (pid=26716)   from ray.tune.suggest.hyperopt import HyperOptSearch
# (pid=26716) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:20: DeprecationWarning: The module `ray.tune.suggest.optuna` has been moved to `ray.tune.search.optuna` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.optuna` with `ray.tune.search.optuna`.
# (pid=26716)   from ray.tune.suggest.optuna import OptunaSearch
# (pid=26833) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest` has been moved to `ray.tune.search` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest` with `ray.tune.search`.
# (pid=26833)   from ray.tune.suggest.suggestion import Searcher
# (pid=26833) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest.suggestion` has been moved to `ray.tune.search.searcher` and the old location will be deprecated soon. Please adjust your imports to point to the new location.
# (pid=26833) ATTENTION: This module may have been split or refactored. Please check the contents of `ray.tune.search.searcher` before making changes.
# (pid=26833)   from ray.tune.suggest.suggestion import Searcher
# (pid=26833) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_basesearch.py:33: DeprecationWarning: The module `ray.tune.trial` has been moved to `ray.tune.experiment.trial` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.trial` with `ray.tune.experiment.trial`.
# (pid=26833)   from ray.tune.trial import Trial
# (pid=26833) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:12: DeprecationWarning: The module `ray.tune.sample` has been moved to `ray.tune.search.sample` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.sample` with `ray.tune.search.sample`.
# (pid=26833)   from ray.tune.sample import Domain
# (pid=26833) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:15: DeprecationWarning: The module `ray.tune.suggest.bohb` has been moved to `ray.tune.search.bohb` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.bohb` with `ray.tune.search.bohb`.
# (pid=26833)   from ray.tune.suggest.bohb import TuneBOHB
# (pid=26833) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:18: DeprecationWarning: The module `ray.tune.suggest.skopt` has been moved to `ray.tune.search.skopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.skopt` with `ray.tune.search.skopt`.
# (pid=26833)   from ray.tune.suggest.skopt import SkOptSearch
# (pid=26833) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:19: DeprecationWarning: The module `ray.tune.suggest.hyperopt` has been moved to `ray.tune.search.hyperopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.hyperopt` with `ray.tune.search.hyperopt`.
# (pid=26833)   from ray.tune.suggest.hyperopt import HyperOptSearch
# (pid=26833) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:20: DeprecationWarning: The module `ray.tune.suggest.optuna` has been moved to `ray.tune.search.optuna` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.optuna` with `ray.tune.search.optuna`.
# (pid=26833)   from ray.tune.suggest.optuna import OptunaSearch
# (pid=26921) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest` has been moved to `ray.tune.search` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest` with `ray.tune.search`.
# (pid=26921)   from ray.tune.suggest.suggestion import Searcher
# (pid=26921) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/list_searcher.py:7: DeprecationWarning: The module `ray.tune.suggest.suggestion` has been moved to `ray.tune.search.searcher` and the old location will be deprecated soon. Please adjust your imports to point to the new location.
# (pid=26921) ATTENTION: This module may have been split or refactored. Please check the contents of `ray.tune.search.searcher` before making changes.
# (pid=26921)   from ray.tune.suggest.suggestion import Searcher
# (pid=26921) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_basesearch.py:33: DeprecationWarning: The module `ray.tune.trial` has been moved to `ray.tune.experiment.trial` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.trial` with `ray.tune.experiment.trial`.
# (pid=26921)   from ray.tune.trial import Trial
# (pid=26921) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:12: DeprecationWarning: The module `ray.tune.sample` has been moved to `ray.tune.search.sample` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.sample` with `ray.tune.search.sample`.
# (pid=26921)   from ray.tune.sample import Domain
# (pid=26921) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:15: DeprecationWarning: The module `ray.tune.suggest.bohb` has been moved to `ray.tune.search.bohb` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.bohb` with `ray.tune.search.bohb`.
# (pid=26921)   from ray.tune.suggest.bohb import TuneBOHB
# (pid=26921) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:18: DeprecationWarning: The module `ray.tune.suggest.skopt` has been moved to `ray.tune.search.skopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.skopt` with `ray.tune.search.skopt`.
# (pid=26921)   from ray.tune.suggest.skopt import SkOptSearch
# (pid=26921) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:19: DeprecationWarning: The module `ray.tune.suggest.hyperopt` has been moved to `ray.tune.search.hyperopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.hyperopt` with `ray.tune.search.hyperopt`.
# (pid=26921)   from ray.tune.suggest.hyperopt import HyperOptSearch
# (pid=26921) /home/lukas/anaconda3/envs/py310/lib/python3.10/site-packages/tune_sklearn/tune_search.py:20: DeprecationWarning: The module `ray.tune.suggest.optuna` has been moved to `ray.tune.search.optuna` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.optuna` with `ray.tune.search.optuna`.
# (pid=26921)   from ray.tune.suggest.optuna import OptunaSearch
# {'learning_rate': 0.1157890594225776, 'max_depth': 17, 'num_leaves': 239, 'min_child_samples': 182, 'colsample_bytree': 0.6117890970477858, 'subsample': 0.6749928477181312}
# {'params': [{'learning_rate': 0.1157890594225776, 'max_depth': 17, 'num_leaves': 239, 'min_child_samples': 182, 'colsample_bytree': 0.6117890970477858, 'subsample': 0.6749928477181312}, {'learning_rate': 0.17583511659304935, 'max_depth': 16, 'num_leaves': 198, 'min_child_samples': 349, 'colsample_bytree': 0.6032250912653214, 'subsample': 0.5887050636322357}, {'learning_rate': 0.08033373947622069, 'max_depth': 17, 'num_leaves': 207, 'min_child_samples': 193, 'colsample_bytree': 0.7150043880203191, 'subsample': 0.5827715550199122}, {'learning_rate': 0.17311724205481518, 'max_depth': 11, 'num_leaves': 142, 'min_child_samples': 236, 'colsample_bytree': 0.7616076046892026, 'subsample': 0.5967911936552674}, {'learning_rate': 0.10158615564375383, 'max_depth': 15, 'num_leaves': 272, 'min_child_samples': 241, 'colsample_bytree': 0.7456574406747384, 'subsample': 0.5830647769914692}, {'learning_rate': 0.14282316300644682, 'max_depth': 12, 'num_leaves': 116, 'min_child_samples': 302, 'colsample_bytree': 

#              mask=[False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object)}

# %%
lgbm_cv.cv_results_
# Out:
# {'params': [{'learning_rate': 0.1157890594225776,
#    'max_depth': 17,
#    'num_leaves': 239,
#    'min_child_samples': 182,
#    'colsample_bytree': 0.6117890970477858,
#    'subsample': 0.6749928477181312},
#   {'learning_rate': 0.17583511659304935,
#    'max_depth': 16,
#    'num_leaves': 198,
#    'min_child_samples': 349,
#    'colsample_bytree': 0.6032250912653214,
#    'subsample': 0.5887050636322357},
#   {'learning_rate': 0.08033373947622069,
#    'max_depth': 17,
#    'num_leaves': 207,
#    'min_child_samples': 193,
#    'colsample_bytree': 0.7150043880203191,
#    'subsample': 0.5827715550199122},
#   {'learning_rate': 0.17311724205481518,
#    'max_depth': 11,
#    'num_leaves': 142,
#    'min_child_samples': 236,
#    'colsample_bytree': 0.7616076046892026,
#    'subsample': 0.5967911936552674},
#   {'learning_rate': 0.10158615564375383,
#    'max_depth': 15,
#    'num_leaves': 272,
#    'min_child_samples': 241,
#    'colsample_bytree': 0.7456574406747384,
#    'subsample': 0.5830647769914692},
#   {'learning_rate': 0.14282316300644682,
#    'max_depth': 12,
#    'num_leaves': 116,
#    'min_child_samples': 302,
#    'colsample_bytree': 0.8914619279154443,
#    'subsample': 0.6329045285701902},
#   {'learning_rate': 0.05121256541794618,
#    'max_depth': 9,
#    'num_leaves': 119,
#    'min_child_samples': 224,
#    'colsample_bytree': 0.8593202748707751,
#    'subsample': 0.6713331502229563},
#   {'learning_rate': 0.13300207339697442,
#    'max_depth': 17,
#    'num_leaves': 187,
#    'min_child_samples': 244,
#    'colsample_bytree': 0.8578352669584681,
#    'subsample': 0.567900660857219},
#   {'learning_rate': 0.1459640009601353,
#    'max_depth': 16,
#    'num_leaves': 205,
#    'min_child_samples': 332,
#    'colsample_bytree': 0.6414950561383734,
#    'subsample': 0.5417406936309868},
#   {'learning_rate': 0.1264897976687166,
#    'max_depth': 8,
#    'num_leaves': 227,
#    'min_child_samples': 294,
#    'colsample_bytree': 0.6292041018994708,
#    'subsample': 0.5769600205998799}],
#  'split0_test_score': array([0.84981655, 0.84062412, 0.84953433, 0.84300286, 0.84759908,
#         0.84663146, 0.8451397 , 0.84586542, 0.84324477, 0.84590574]),
#  'split1_test_score': array([0.85816726, 0.84882848, 0.85783374, 0.84953723, 0.85308096,
#         0.85349787, 0.85274744, 0.85378971, 0.85091303, 0.85462353]),
#  'split2_test_score': array([0.84197486, 0.82670391, 0.84129916, 0.82706428, 0.83003739,
#         0.83098338, 0.82674895, 0.82742466, 0.83030767, 0.83395648]),
#  'mean_test_score': array([0.84998623, 0.83871884, 0.84955574, 0.83986812, 0.84357248,
#         0.84370424, 0.84154536, 0.84235993, 0.84148849, 0.84482858]),
#  'std_test_score': array([0.00661161, 0.00913224, 0.00675023, 0.00943851, 0.00982893,
#         0.00942168, 0.0109139 , 0.01104522, 0.00850328, 0.0084716 ]),
#  'rank_test_score': array([ 1, 10,  2,  9,  5,  4,  7,  6,  8,  3], dtype=int32),
#  'time_total_s': array([1216.3209126 ,   17.40472841, 1194.11535406,   20.9661088 ,
#           24.12199736,   19.34291697,   21.1673491 ,   23.96420979,
#           15.88666701,   76.7099309 ]),
#  'training_iteration': array([20,  1, 16,  1,  1,  1,  1,  1,  1,  4]),
#  'param_learning_rate': masked_array(data=[0.1157890594225776, 0.17583511659304935,
#                     0.08033373947622069, 0.17311724205481518,
#                     0.10158615564375383, 0.14282316300644682,
#                     0.05121256541794618, 0.13300207339697442,
#                     0.1459640009601353, 0.1264897976687166],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[17, 16, 17, 11, 15, 12, 9, 17, 16, 8],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_num_leaves': masked_array(data=[239, 198, 207, 142, 272, 116, 119, 187, 205, 227],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_child_samples': masked_array(data=[182, 349, 193, 236, 241, 302, 224, 244, 332, 294],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_colsample_bytree': masked_array(data=[0.6117890970477858, 0.6032250912653214,
#                     0.7150043880203191, 0.7616076046892026,
#                     0.7456574406747384, 0.8914619279154443,
#                     0.8593202748707751, 0.8578352669584681,
#                     0.6414950561383734, 0.6292041018994708],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_subsample': masked_array(data=[0.6749928477181312, 0.5887050636322357,
#                     0.5827715550199122, 0.5967911936552674,
#                     0.5830647769914692, 0.6329045285701902,
#                     0.6713331502229563, 0.567900660857219,
#                     0.5417406936309868, 0.5769600205998799],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object)}

# %%
print(lgbm_cv.best_params_)
# Out:
# {'learning_rate': 0.1157890594225776, 'max_depth': 17, 'num_leaves': 239, 'min_child_samples': 182, 'colsample_bytree': 0.6117890970477858, 'subsample': 0.6749928477181312}

# %%
lightgbm_params = {
     'boosting_type': 'goss',
     'learning_rate': 0.1, 
     'max_depth': 10, 
     'num_leaves': 200,
     'min_child_samples': 250,
     'colsample_bytree': 0.8, 
     'subsample': 0.6, 
     "seed": 1
    }

# %%
pred = lgbm_cv.predict(X_test)
correct = 0
for i in range(len(y_test)):
    if pred[i] == y_test[i]:
        correct += 1
print("Accuracy:", correct / len(pred))
# Out:
# Accuracy: 0.9736842105263158

# %%
gs.cv_results_
# Out:
# {'params': [{'learning_rate': 0.050847414312614324,
#    'max_depth': 17,
#    'num_leaves': 233,
#    'min_child_samples': 333,
#    'colsample_bytree': 0.6650951599053373,
#    'subsample': 0.5664499007552558},
#   {'learning_rate': 0.15671882556207622,
#    'max_depth': 7,
#    'num_leaves': 207,
#    'min_child_samples': 284,
#    'colsample_bytree': 0.685689293137132,
#    'subsample': 0.5271388959097277},
#   {'learning_rate': 0.13893435113882024,
#    'max_depth': 18,
#    'num_leaves': 261,
#    'min_child_samples': 340,
#    'colsample_bytree': 0.7197933899906809,
#    'subsample': 0.5084740941617972},
#   {'learning_rate': 0.10444470952801721,
#    'max_depth': 14,
#    'num_leaves': 225,
#    'min_child_samples': 278,
#    'colsample_bytree': 0.790288176096368,
#    'subsample': 0.6705123704817287},
#   {'learning_rate': 0.10321509580810687,
#    'max_depth': 10,
#    'num_leaves': 224,
#    'min_child_samples': 229,
#    'colsample_bytree': 0.7582510650835258,
#    'subsample': 0.626682376001814},
#   {'learning_rate': 0.19449797385910417,
#    'max_depth': 13,
#    'num_leaves': 210,
#    'min_child_samples': 320,
#    'colsample_bytree': 0.7632888079521151,
#    'subsample': 0.6762700484216851},
#   {'learning_rate': 0.10731345521408316,
#    'max_depth': 12,
#    'num_leaves': 243,
#    'min_child_samples': 303,
#    'colsample_bytree': 0.7397124792180578,
#    'subsample': 0.5584554869621795},
#   {'learning_rate': 0.07103562928526404,
#    'max_depth': 8,
#    'num_leaves': 246,
#    'min_child_samples': 330,
#    'colsample_bytree': 0.650212102780801,
#    'subsample': 0.6750143154251856},
#   {'learning_rate': 0.14041876292754818,
#    'max_depth': 11,
#    'num_leaves': 118,
#    'min_child_samples': 314,
#    'colsample_bytree': 0.6704821222677959,
#    'subsample': 0.6837594412812422},
#   {'learning_rate': 0.1561665014012574,
#    'max_depth': 13,
#    'num_leaves': 215,
#    'min_child_samples': 191,
#    'colsample_bytree': 0.8103854265618404,
#    'subsample': 0.6680179969040875},
#   {'learning_rate': 0.1666000616107034,
#    'max_depth': 9,
#    'num_leaves': 213,
#    'min_child_samples': 327,
#    'colsample_bytree': 0.7718009405246199,
#    'subsample': 0.5282187232327371},
#   {'learning_rate': 0.14306570195854168,
#    'max_depth': 9,
#    'num_leaves': 159,
#    'min_child_samples': 247,
#    'colsample_bytree': 0.6339815307275072,
#    'subsample': 0.6861671576283873},
#   {'learning_rate': 0.1862472843295762,
#    'max_depth': 15,
#    'num_leaves': 110,
#    'min_child_samples': 282,
#    'colsample_bytree': 0.8570269807244462,
#    'subsample': 0.5963628752260235},
#   {'learning_rate': 0.05877962402564339,
#    'max_depth': 18,
#    'num_leaves': 211,
#    'min_child_samples': 263,
#    'colsample_bytree': 0.6430902882597912,
#    'subsample': 0.6244321596547622},
#   {'learning_rate': 0.06315194858557271,
#    'max_depth': 18,
#    'num_leaves': 117,
#    'min_child_samples': 150,
#    'colsample_bytree': 0.8770131312369729,
#    'subsample': 0.6030968495498035},
#   {'learning_rate': 0.12927157731449052,
#    'max_depth': 18,
#    'num_leaves': 132,
#    'min_child_samples': 336,
#    'colsample_bytree': 0.8632444824644896,
#    'subsample': 0.6658900510673187},
#   {'learning_rate': 0.17696336604064766,
#    'max_depth': 12,
#    'num_leaves': 187,
#    'min_child_samples': 152,
#    'colsample_bytree': 0.6047118965791297,
#    'subsample': 0.6289945061366068},
#   {'learning_rate': 0.12461424166826468,
#    'max_depth': 5,
#    'num_leaves': 265,
#    'min_child_samples': 165,
#    'colsample_bytree': 0.8359992363034802,
#    'subsample': 0.5821295043858493},
#   {'learning_rate': 0.061731685285175676,
#    'max_depth': 11,
#    'num_leaves': 217,
#    'min_child_samples': 310,
#    'colsample_bytree': 0.8096763439311783,
#    'subsample': 0.6875772391601913},
#   {'learning_rate': 0.19710801318605342,
#    'max_depth': 17,
#    'num_leaves': 254,
#    'min_child_samples': 177,
#    'colsample_bytree': 0.6095946165808459,
#    'subsample': 0.6114838052685195},
#   {'learning_rate': 0.1414291404638246,
#    'max_depth': 15,
#    'num_leaves': 132,
#    'min_child_samples': 172,
#    'colsample_bytree': 0.7548264701169776,
#    'subsample': 0.6986817276749634},
#   {'learning_rate': 0.06127288600481841,
#    'max_depth': 19,
#    'num_leaves': 202,
#    'min_child_samples': 209,
#    'colsample_bytree': 0.7414550885419466,
#    'subsample': 0.6091634960965456},
#   {'learning_rate': 0.09938789642437265,
#    'max_depth': 17,
#    'num_leaves': 134,
#    'min_child_samples': 204,
#    'colsample_bytree': 0.7478924217234876,
#    'subsample': 0.6365376552503821},
#   {'learning_rate': 0.1641957423335783,
#    'max_depth': 16,
#    'num_leaves': 240,
#    'min_child_samples': 206,
#    'colsample_bytree': 0.6911551659357873,
#    'subsample': 0.6705023398606998},
#   {'learning_rate': 0.1985345829052501,
#    'max_depth': 19,
#    'num_leaves': 284,
#    'min_child_samples': 229,
#    'colsample_bytree': 0.6861545629764965,
#    'subsample': 0.5197927558166558},
#   {'learning_rate': 0.08187938651821544,
#    'max_depth': 8,
#    'num_leaves': 194,
#    'min_child_samples': 259,
#    'colsample_bytree': 0.8512097118238992,
#    'subsample': 0.5167579370453587},
#   {'learning_rate': 0.19361018806234265,
#    'max_depth': 12,
#    'num_leaves': 118,
#    'min_child_samples': 318,
#    'colsample_bytree': 0.6638906639428708,
#    'subsample': 0.647828252428094},
#   {'learning_rate': 0.09401219986817583,
#    'max_depth': 14,
#    'num_leaves': 190,
#    'min_child_samples': 206,
#    'colsample_bytree': 0.8209062544414992,
#    'subsample': 0.6704955400340366},
#   {'learning_rate': 0.05,
#    'max_depth': 5,
#    'num_leaves': 100,
#    'min_child_samples': 150,
#    'colsample_bytree': 0.9,
#    'subsample': 0.5},
#   {'learning_rate': 0.19620129736267022,
#    'max_depth': 6,
#    'num_leaves': 105,
#    'min_child_samples': 158,
#    'colsample_bytree': 0.8796385427912323,
#    'subsample': 0.5202213458979605},
#   {'learning_rate': 0.05,
#    'max_depth': 5,
#    'num_leaves': 100,
#    'min_child_samples': 150,
#    'colsample_bytree': 0.9,
#    'subsample': 0.5},
#   {'learning_rate': 0.1879089516736655,
#    'max_depth': 8,
#    'num_leaves': 171,
#    'min_child_samples': 174,
#    'colsample_bytree': 0.8870229427754437,
#    'subsample': 0.5271495976556194},
#   {'learning_rate': 0.058032987040768,
#    'max_depth': 10,
#    'num_leaves': 182,
#    'min_child_samples': 336,
#    'colsample_bytree': 0.7660170721435168,
#    'subsample': 0.526234299342955},
#   {'learning_rate': 0.05,
#    'max_depth': 5,
#    'num_leaves': 100,
#    'min_child_samples': 350,
#    'colsample_bytree': 0.6,
#    'subsample': 0.7},
#   {'learning_rate': 0.2,
#    'max_depth': 5,
#    'num_leaves': 300,
#    'min_child_samples': 150,
#    'colsample_bytree': 0.8783202407876035,
#    'subsample': 0.5},
#   {'learning_rate': 0.08084521359518398,
#    'max_depth': 5,
#    'num_leaves': 295,
#    'min_child_samples': 158,
#    'colsample_bytree': 0.6,
#    'subsample': 0.5},
#   {'learning_rate': 0.1035195448104922,
#    'max_depth': 10,
#    'num_leaves': 174,
#    'min_child_samples': 158,
#    'colsample_bytree': 0.7581111992508975,
#    'subsample': 0.5360007621539656},
#   {'learning_rate': 0.05,
#    'max_depth': 20,
#    'num_leaves': 134,
#    'min_child_samples': 158,
#    'colsample_bytree': 0.9,
#    'subsample': 0.507454202206194},
#   {'learning_rate': 0.14000961526849345,
#    'max_depth': 20,
#    'num_leaves': 260,
#    'min_child_samples': 160,
#    'colsample_bytree': 0.6406392672140323,
#    'subsample': 0.6863509540797719},
#   {'learning_rate': 0.05,
#    'max_depth': 20,
#    'num_leaves': 300,
#    'min_child_samples': 155,
#    'colsample_bytree': 0.9,
#    'subsample': 0.7},
#   {'learning_rate': 0.05,
#    'max_depth': 19,
#    'num_leaves': 100,
#    'min_child_samples': 155,
#    'colsample_bytree': 0.9,
#    'subsample': 0.7},
#   {'learning_rate': 0.05,
#    'max_depth': 20,
#    'num_leaves': 100,
#    'min_child_samples': 155,
#    'colsample_bytree': 0.9,
#    'subsample': 0.7},
#   {'learning_rate': 0.2,
#    'max_depth': 20,
#    'num_leaves': 300,
#    'min_child_samples': 155,
#    'colsample_bytree': 0.9,
#    'subsample': 0.6094555421307098},
#   {'learning_rate': 0.1977439308332764,
#    'max_depth': 6,
#    'num_leaves': 123,
#    'min_child_samples': 154,
#    'colsample_bytree': 0.7881115956242112,
#    'subsample': 0.6828931010697455},
#   {'learning_rate': 0.2,
#    'max_depth': 19,
#    'num_leaves': 194,
#    'min_child_samples': 169,
#    'colsample_bytree': 0.6,
#    'subsample': 0.5},
#   {'learning_rate': 0.2,
#    'max_depth': 5,
#    'num_leaves': 177,
#    'min_child_samples': 169,
#    'colsample_bytree': 0.6,
#    'subsample': 0.5659664832336465},
#   {'learning_rate': 0.2,
#    'max_depth': 5,
#    'num_leaves': 289,
#    'min_child_samples': 169,
#    'colsample_bytree': 0.6,
#    'subsample': 0.5947848243188828},
#   {'learning_rate': 0.2,
#    'max_depth': 5,
#    'num_leaves': 300,
#    'min_child_samples': 172,
#    'colsample_bytree': 0.7849082216063705,
#    'subsample': 0.5},
#   {'learning_rate': 0.2,
#    'max_depth': 5,
#    'num_leaves': 300,
#    'min_child_samples': 150,
#    'colsample_bytree': 0.9,
#    'subsample': 0.7},
#   {'learning_rate': 0.2,
#    'max_depth': 5,
#    'num_leaves': 300,
#    'min_child_samples': 150,
#    'colsample_bytree': 0.9,
#    'subsample': 0.7}],
#  'split0_test_score': array([0.63736264, 0.63736264, 0.63736264, 0.63736264, 0.63736264,
#         0.63736264, 0.63736264, 0.63736264, 0.63736264, 0.63736264,
#         0.63736264, 0.63736264, 0.63736264, 0.63736264, 0.95604396,
#         0.63736264, 0.96703297, 0.95604396, 0.63736264, 0.95604396,
#         0.94505495, 0.63736264, 0.63736264, 0.63736264, 0.63736264,
#         0.63736264, 0.63736264, 0.63736264, 0.93406593, 0.96703297,
#         0.93406593, 0.96703297, 0.63736264, 0.63736264, 0.97802198,
#         0.96703297, 0.95604396, 0.92307692, 0.95604396, 0.91208791,
#         0.91208791, 0.91208791, 0.96703297, 0.97802198, 0.95604396,
#         0.95604396, 0.95604396, 0.96703297, 0.97802198, 0.97802198]),
#  'split1_test_score': array([0.62637363, 0.62637363, 0.62637363, 0.62637363, 0.62637363,
#         0.62637363, 0.62637363, 0.62637363, 0.62637363, 0.62637363,
#         0.62637363, 0.62637363, 0.62637363, 0.62637363, 0